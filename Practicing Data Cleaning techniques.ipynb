# %%
import pandas as pd
import numpy as np

data_frame = pd.read_csv(r"C:\Users\abasit\Downloads\titanic_test.csv")

data_frame
# Out:
#      passenger_id  pclass                            name     sex  ...  embarked  boat  body              home.dest
# 0             295       1     Thayer, Mr. John Borland Jr    male  ...         C     B   NaN          Haverford, PA
# 1            1150       3        Risien, Mr. Samuel Beard    male  ...         S   NaN   NaN                    NaN
# 2              89       1          Davidson, Mr. Thornton    male  ...         S   NaN   NaN           Montreal, PQ
# 3            1063       3  Nirva, Mr. Iisakki Antino Aijo    male  ...         S   NaN   NaN    Finland Sudbury, ON
# 4            1020       3              Minkoff, Mr. Lazar    male  ...         S   NaN   NaN                    NaN
# ..            ...     ...                             ...     ...  ...       ...   ...   ...                    ...
# 454          1194       3              Sdycoff, Mr. Todor    male  ...         S   NaN   NaN                    NaN
# ...

# %%
#data_frame = data_frame.applymap(np.int64)
data_frame = data_frame.loc[data_frame.age.notna()]
data_frame
# Out:
#      passenger_id  pclass                                     name     sex  ...  embarked  boat  body              home.dest
# 0             295       1              Thayer, Mr. John Borland Jr    male  ...         C     B   NaN          Haverford, PA
# 2              89       1                   Davidson, Mr. Thornton    male  ...         S   NaN   NaN           Montreal, PQ
# 3            1063       3           Nirva, Mr. Iisakki Antino Aijo    male  ...         S   NaN   NaN    Finland Sudbury, ON
# 4            1020       3                       Minkoff, Mr. Lazar    male  ...         S   NaN   NaN                    NaN
# 5             747       3  Danbom, Master. Gilbert Sigvard Emanuel    male  ...         S   NaN   NaN            Stanton, IA
# ..            ...     ...                                      ...     ...  ...       ...   ...   ...                    ...
# ...

# %%
sib_groupby = data_frame.groupby
